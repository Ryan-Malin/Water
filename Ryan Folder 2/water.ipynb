# %%
import pandas as pd

# %%
water = pd.read_csv("../water_potability.csv")

# %%
water['SampleNumber'] = water.index

# %%
water.shape
# Out:
# (3276, 11)

# %%
water.dropna()
water.reset_index()
# Out:
#       index        ph    Hardness        Solids  Chloramines     Sulfate  \
# 0         0       NaN  204.890455  20791.318981     7.300212  368.516441
# 1         1  3.716080  129.422921  18630.057858     6.635246         NaN
# 2         2  8.099124  224.236259  19909.541732     9.275884         NaN
# 3         3  8.316766  214.373394  22018.417441     8.059332  356.886136
# 4         4  9.092223  181.101509  17978.986339     6.546600  310.135738
# ...     ...       ...         ...           ...          ...         ...
# 3271   3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272   3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273   3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274   3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275   3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability  \
# ...

# %%
#water = water.sort_values("ph", ascending=False).reset_index(drop=True)
#water['ph_rank'] = water.index

# %%
water.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability',
#        'SampleNumber'],
#       dtype='object')

# %%
water['ph_rank'] = water[water['ph'].notnull()].groupby('ph', sort=True).ngroup()+1
water['ph_rank'] = water['ph_rank'].fillna('')

# %%
water['Hardness_rank'] = water[water['Hardness'].notnull()].groupby('Hardness', sort=True).ngroup()+1
water['Hardness_rank'] = water['Hardness'].fillna('')

# %%
water['Solids_rank'] = water[water['Solids'].notnull()].groupby('Solids', sort=True).ngroup()+1
water['Solids_rank'] = water['Solids_rank'].fillna('')

# %%
water['Chloramines_rank'] = water[water['Chloramines'].notnull()].groupby('Chloramines', sort=True).ngroup()+1
water['Chloramines_rank'] = water['Chloramines_rank'].fillna('')

# %%
water['Sulfate_rank'] = water[water['Sulfate'].notnull()].groupby('Sulfate', sort=True).ngroup()+1
water['Sulfate_rank'] = water['Sulfate_rank'].fillna('')

# %%
water['Conductivity_rank'] = water[water['Conductivity'].notnull()].groupby('Conductivity', sort=True).ngroup()+1
water['Conductivity_rank'] = water['Conductivity_rank'].fillna('')

# %%
water['Organic_carbon_rank'] = water[water['Organic_carbon'].notnull()].groupby('Organic_carbon', sort=True).ngroup()+1
water['Organic_carbon_rank'] = water['Organic_carbon_rank'].fillna('')

# %%
water['Trihalomethanes_rank'] = water[water['Trihalomethanes'].notnull()].groupby('Trihalomethanes', sort=True).ngroup()+1
water['Trihalomethanes_rank'] = water['Trihalomethanes_rank'].fillna('')

# %%
water['Turbidity_rank'] = water[water['Turbidity'].notnull()].groupby('Turbidity', sort=True).ngroup()+1
water['Turbidity_rank'] = water['Turbidity_rank'].fillna('')

# %%
water
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability  \
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
water["Average_Rank"] = water[['ph_rank', 'Hardness_rank', 'Solids_rank',
       'Chloramines_rank', 'Sulfate_rank', 'Conductivity_rank',
       'Organic_carbon_rank', 'Trihalomethanes_rank', 'Turbidity_rank']].mean(numeric_only=True, axis=1)

# %%
water = water.sort_values("Average_Rank", ascending=True).reset_index(drop=True)
water['Average_Rank_2'] = water.index

# %%
#water.to_csv('water1.csv', index=False)

# %%
water
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 0           NaN  226.548354  13584.490338     4.190696  374.157621
# 1      5.626340  230.857983  14442.418875     5.210369         NaN
# 2           NaN  254.125389   9959.135015     4.008584         NaN
# 3      9.076318  215.912723  14153.643378     5.020027  333.499203
# 4           NaN  199.383091   5576.628297     4.998844  341.088342
# ...         ...         ...           ...          ...         ...
# 3271   6.761414  216.532498  32156.819439     8.723064  343.601104
# 3272   6.770095  201.650854  25887.631722     9.367533  327.619453
# 3273        NaN  186.873014  26004.528877     8.493529  320.693485
# 3274   7.154736  198.147326  32680.977991     8.972661  283.108492
# 3275  10.003301  143.094285  46113.957485    12.912187         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability  \
# 0       335.378212        9.147436        82.864929   2.364559           0
# ...

# %%
water_dropna = water.dropna()
water_dropna.shape
# Out:
# (2011, 22)

# %%
agg = water[['Hardness', 'ph', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
       'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability',
       'SampleNumber']].count()

df = pd.DataFrame({'Non-NaN': agg, 'NaN Values': 3276-agg})

# %%
df
# Out:
#                  Non-NaN  NaN Values
# Hardness            3276           0
# ph                  2785         491
# Solids              3276           0
# Chloramines         3276           0
# Sulfate             2495         781
# Conductivity        3276           0
# Organic_carbon      3276           0
# Trihalomethanes     3114         162
# Turbidity           3276           0
# Potability          3276           0
# SampleNumber        3276           0

# %%
#Hardness: 60 to 200
#ph: 6.5 - 8.5
#Solids < 500 mg/L
#Chloramines: 4mg/L
#Sulfate <250 mg/L
#Conductivity < 400
#Organic Carbon < 2mg/L
#Trihalomethanes <80
#Turbidity < 5.0
water.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability',
#        'SampleNumber', 'ph_rank', 'Hardness_rank', 'Solids_rank',
#        'Chloramines_rank', 'Sulfate_rank', 'Conductivity_rank',
#        'Organic_carbon_rank', 'Trihalomethanes_rank', 'Turbidity_rank',
#        'Average_Rank', 'Average_Rank_2'],
#       dtype='object')

# %%
#water[(water['Hardness']>=60) & (water['Hardness']<=200) & (water['Hardness'] != "NaN")]
water['Hardness_Safe'] = (water['Hardness']>=60) & (water['Hardness']<200) & (water['Hardness']!='NaN')
water['ph_safe'] = (water['ph']>=6.5) & (water['ph']<8.5) & (water['ph']!='NaN')
water['Solids_safe'] = (water['Solids']<=1000) & (water['Solids']!='NaN')
water['Chloramines_safe'] = (water['Chloramines']<=4) & (water['Chloramines']!='NaN')
water['Sulfate_safe'] = (water['Sulfate']<250) & (water['Sulfate']!='NaN')
water['Conductivity_safe'] = (water['Conductivity']<400) & (water['Conductivity']!='NaN')
water['Organic_carbon_safe'] = (water['Organic_carbon']<2) & (water['Organic_carbon']!='NaN')
water['Trihalomethanes_safe'] = (water['Trihalomethanes']<80) & (water['Trihalomethanes']!='NaN')
water['Turbidity_safe'] = (water['Turbidity']<5) & (water['Turbidity']!='NaN')


water
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 0           NaN  226.548354  13584.490338     4.190696  374.157621
# 1      5.626340  230.857983  14442.418875     5.210369         NaN
# 2           NaN  254.125389   9959.135015     4.008584         NaN
# 3      9.076318  215.912723  14153.643378     5.020027  333.499203
# 4           NaN  199.383091   5576.628297     4.998844  341.088342
# ...         ...         ...           ...          ...         ...
# 3271   6.761414  216.532498  32156.819439     8.723064  343.601104
# 3272   6.770095  201.650854  25887.631722     9.367533  327.619453
# 3273        NaN  186.873014  26004.528877     8.493529  320.693485
# 3274   7.154736  198.147326  32680.977991     8.972661  283.108492
# 3275  10.003301  143.094285  46113.957485    12.912187         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability  \
# 0       335.378212        9.147436        82.864929   2.364559           0
# ...

# %%
water.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability',
#        'SampleNumber', 'ph_rank', 'Hardness_rank', 'Solids_rank',
#        'Chloramines_rank', 'Sulfate_rank', 'Conductivity_rank',
#        'Organic_carbon_rank', 'Trihalomethanes_rank', 'Turbidity_rank',
#        'Average_Rank', 'Average_Rank_2', 'Hardness_Safe', 'ph_safe',
#        'Solids_safe', 'Chloramines_safe', 'Sulfate_safe', 'Conductivity_safe',
#        'Organic_carbon_safe', 'Trihalomethanes_safe', 'Turbidity_safe'],
#       dtype='object')

# %%
water["Hardness_Safe_qty"] = water["Hardness_Safe"].sum()
water["ph_safe_qty"] = water["ph_safe"].sum()
water["Solids_safe_qty"] = water["Solids_safe"].sum()
water["Chloramines_safe_qty"] = water["Chloramines_safe"].sum()
water["Sulfate_safe_qty"] = water["Sulfate_safe"].sum()
water["Conductivity_safe_qty"] = water["Conductivity_safe"].sum()
water["Organic_carbon_safe_qty"] = water["Organic_carbon_safe"].sum()
water["Trihalomethanes_safe_qty"] = water["Trihalomethanes_safe"].sum()
water["Turbidity_safe_qty"] = water["Turbidity_safe"].sum()

# %%
water["Hardness_Safe_pct"] = (water["Hardness_Safe"].sum()/32.76).round(2)
water["ph_safe_pct"] = (water["ph_safe"].sum()/32.76).round(2)
water["Solids_safe_pct"] = (water["Solids_safe"].sum()/32.76).round(2)
water["Chloramines_safe_pct"] = (water["Chloramines_safe"].sum()/32.76).round(2)
water["Sulfate_safe_pct"] = (water["Sulfate_safe"].sum()/32.76).round(2)
water["Conductivity_safe_pct"] = (water["Conductivity_safe"].sum()/32.76).round(2)
water["Organic_carbon_safe_pct"] = (water["Organic_carbon_safe"].sum()/32.76).round(2)
water["Trihalomethanes_safe_pct"] = (water["Trihalomethanes_safe"].sum()/32.76).round(2)
water["Turbidity_safe_pct"] = (water["Turbidity_safe"].sum()/32.76).round(2)

# %%
water["Average_Rank"] = water["Average_Rank"].round(0)

# %%
water = water[['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
       'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability',
       'SampleNumber', 'ph_rank', 'Hardness_rank', 'Solids_rank',
       'Chloramines_rank', 'Sulfate_rank', 'Conductivity_rank',
       'Organic_carbon_rank', 'Trihalomethanes_rank', 'Turbidity_rank',
       'Average_Rank', 'Average_Rank_2', 'Hardness_Safe', 'ph_safe',
       'Solids_safe', 'Chloramines_safe', 'Sulfate_safe', 'Conductivity_safe',
       'Organic_carbon_safe', 'Trihalomethanes_safe', 'Turbidity_safe',
       'Hardness_Safe_qty', 'ph_safe_qty', 'Solids_safe_qty',
       'Chloramines_safe_qty', 'Sulfate_safe_qty', 'Conductivity_safe_qty',
       'Organic_carbon_safe_qty', 'Trihalomethanes_safe_qty',
       'Turbidity_safe_qty', 'Hardness_Safe_pct', 'ph_safe_pct',
       'Solids_safe_pct', 'Chloramines_safe_pct', 'Sulfate_safe_pct',
       'Conductivity_safe_pct', 'Organic_carbon_safe_pct',
       'Trihalomethanes_safe_pct', 'Turbidity_safe_pct']].round(2)

# %%
#water.to_csv('water2.csv', index=False)

# %%
#Solids is apparently not accurate
#Organic carbon is also not accurate
water3 = water.dropna()

# %%
#water3.to_csv('water_Ryan.csv', index=False)

# %%
water["Solids"].max()
# Out:
# 61227.2

# %%
water4 = water3.drop(columns=["Solids", "Organic_carbon","Chloramines", "Sulfate", 
                              "Solids_rank", "Organic_carbon_rank","Chloramines_rank","Sulfate_rank",
                             "Solids_safe", "Organic_carbon_safe", "Chloramines_safe", "Sulfate_safe",
                             "Solids_safe_qty", "Organic_carbon_safe_qty", "Chloramines_safe_qty", "Sulfate_safe_qty",
                             "Solids_safe_pct", "Organic_carbon_safe_pct", "Chloramines_safe_pct", "Sulfate_safe_pct"])

# %%
water4
# Out:
#         ph  Hardness  Conductivity  Trihalomethanes  Turbidity  Potability  \
# 3     9.08    215.91        311.80            69.11       3.44           0
# 6     7.18    225.12        294.99            81.45       4.01           0
# 8     9.61    231.34        328.90            78.57       3.04           0
# 9     8.25    175.91        302.20            71.44       3.94           0
# 10    6.68    228.30        254.39            64.78       3.45           1
# ...    ...       ...           ...              ...        ...         ...
# 3269  5.75    241.60        495.95            71.43       5.92           0
# 3270  8.33    213.87        569.10            62.79       4.40           0
# 3271  6.76    216.53        526.33            60.52       4.35           1
# 3272  6.77    201.65        519.38            90.06       5.20           1
# 3274  7.15    198.15        531.60            81.93       4.63           1
#
#       SampleNumber ph_rank  Hardness_rank  Conductivity_rank  ...  \
# ...

# %%
water4[['Hardness_Safe', 'ph_safe','Conductivity_safe',
       'Trihalomethanes_safe', 'Turbidity_safe']]
# Out:
#       Hardness_Safe  ph_safe  Conductivity_safe  Trihalomethanes_safe  \
# 3             False    False               True                  True
# 6             False     True               True                 False
# 8             False    False               True                  True
# 9              True     True               True                  True
# 10            False     True               True                  True
# ...             ...      ...                ...                   ...
# 3269          False    False              False                  True
# 3270          False     True              False                  True
# 3271          False     True              False                  True
# 3272          False     True              False                 False
# 3274           True     True              False                 False
#
#       Turbidity_safe
# 3               True
# 6               True
# 8               True
# 9               True
# ...

# %%
def check(x):
    if x['Hardness_Safe'] == True & x['ph_safe'] == True & x['Conductivity_safe'] == True & x['Trihalomethanes_safe'] == True & x['Turbidity_safe'] == True:
        return True
    else:
        return False
water4['Potable_WHO_Standards'] = water4.apply(check, axis=1)

# %%
def potable(y):
    if y['Potability'] == 1:
        return True
    else:
        return False
water4['Potability'] = water4.apply(potable, axis=1)

# %%
water4[['Potable_WHO_Standards', 'Potability']]
# Out:
#       Potable_WHO_Standards  Potability
# 3                     False       False
# 6                     False       False
# 8                     False       False
# 9                      True       False
# 10                    False        True
# ...                     ...         ...
# 3269                  False       False
# 3270                  False       False
# 3271                  False        True
# 3272                  False        True
# 3274                  False        True
#
# [2011 rows x 2 columns]

# %%
water4['Potable_WHO_Standards'].count()
# Out:
# 2011

# %%
water4['Potability'].count()
# Out:
# 2011

# %%
WHO_True = len(water4[water4.Potable_WHO_Standards == True])

# %%
Pot_True = len(water4[water4.Potability == True])

# %%
WHO_False = len(water4[water4.Potable_WHO_Standards == False])

# %%
Pot_False = len(water4[water4.Potability == False])

# %%
WHO_True + Pot_True + WHO_False + Pot_False
# Out:
# 4022

# %%
def conflict(x):
    if x['Potable_WHO_Standards'] == x['Potability']:
        return 'No Conflict'
    else:
        return 'Conflict'
water4['Conflict'] = water4.apply(conflict, axis=1)

# %%
water4[water4.Conflict == 'Conflict'].shape
# Out:
# (821, 32)

# %%
water4[water4.Conflict == 'No Conflict'].shape
# Out:
# (1190, 32)

# %%
water4[water4.Potable_WHO_Standards & water4.Potability == True].shape
# Out:
# (66, 32)

# %%
water4[water4.Potable_WHO_Standards & water4.Potability == False].shape
# Out:
# (1945, 32)

# %%
water4['Conflict']
# Out:
# 3       No Conflict
# 6       No Conflict
# 8       No Conflict
# 9          Conflict
# 10         Conflict
#            ...
# 3269    No Conflict
# 3270    No Conflict
# 3271       Conflict
# 3272       Conflict
# 3274       Conflict
# Name: Conflict, Length: 2011, dtype: object

# %%
water4.drop(columns=['Potable_Manual'])
# Out:
#         ph  Hardness  Conductivity  Trihalomethanes  Turbidity  Potability  \
# 3     9.08    215.91        311.80            69.11       3.44       False
# 6     7.18    225.12        294.99            81.45       4.01       False
# 8     9.61    231.34        328.90            78.57       3.04       False
# 9     8.25    175.91        302.20            71.44       3.94       False
# 10    6.68    228.30        254.39            64.78       3.45        True
# ...    ...       ...           ...              ...        ...         ...
# 3269  5.75    241.60        495.95            71.43       5.92       False
# 3270  8.33    213.87        569.10            62.79       4.40       False
# 3271  6.76    216.53        526.33            60.52       4.35        True
# 3272  6.77    201.65        519.38            90.06       5.20        True
# 3274  7.15    198.15        531.60            81.93       4.63        True
#
#       SampleNumber ph_rank  Hardness_rank  Conductivity_rank  ...  \
# ...

# %%
water4[['Potability', 'Potable_WHO_Standards', 'Conflict']]
# Out:
#       Potability  Potable_WHO_Standards     Conflict
# 3          False                  False  No Conflict
# 6          False                  False  No Conflict
# 8          False                  False  No Conflict
# 9          False                   True     Conflict
# 10          True                  False     Conflict
# ...          ...                    ...          ...
# 3269       False                  False  No Conflict
# 3270       False                  False  No Conflict
# 3271        True                  False     Conflict
# 3272        True                  False     Conflict
# 3274        True                  False     Conflict
#
# [2011 rows x 3 columns]

# %%
water4[water4.Conflict == 'No Conflict'].shape
# Out:
# (1190, 32)

# %%
water4[water4.Conflict == 'Conflict'].shape
# Out:
# (821, 32)
